# %% [markdown]
# # Multi-agent supervisor
#
# The [previous example](../multi-agent-collaboration) routed messages automatically based on the output of the initial researcher agent.
#
# We can also choose to use an [LLM to orchestrate](https://langchain-ai.github.io/langgraph/concepts/multi_agent/#supervisor) the different agents.
#
# Below, we will create an agent group, with an agent supervisor to help delegate tasks.
#
# ![diagram](attachment:8ee0a8ce-f0a8-4019-b5bf-b20933e40956.png)
#
# To simplify the code in each agent node, we will use LangGraph's prebuilt [create_react_agent](https://langchain-ai.github.io/langgraph/reference/prebuilt/#langgraph.prebuilt.chat_agent_executor.create_react_agent). This and other "advanced agent" notebooks are designed to show how you can implement certain design patterns in LangGraph. If the pattern suits your needs, we recommend combining it with some of the other fundamental patterns described elsewhere in the docs for best performance.
#
# ## Setup
#
# First, let's install required packages and set our API keys

# %%
# %%capture --no-stderr
# %pip install -U langgraph langchain_community langchain_anthropic langchain_experimental

# %%
import getpass
import os

def _set_if_undefined(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"Please provide your {var}")

_set_if_undefined("ANTHROPIC_API_KEY")
_set_if_undefined("TAVILY_API_KEY")

# %% [markdown]
# <div class="admonition tip">
#     <p class="admonition-title">Set up <a href="https://smith.langchain.com">LangSmith</a> for LangGraph development</p>
#     <p style="padding-top: 5px;">
#         Sign up for LangSmith to quickly spot issues and improve the performance of your LangGraph projects. LangSmith lets you use trace data to debug, test, and monitor your LLM apps built with LangGraph — read more about how to get started <a href="https://docs.smith.langchain.com">here</a>.
#     </p>
# </div>

# %% [markdown]
# ## Create tools
#
# For this example, you will make an agent to do web research with a search engine, and one agent to create plots. Define the tools they'll use below:

# %%
from typing import Annotated

from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_core.tools import tool
from langchain_experimental.utilities import PythonREPL

tavily_tool = TavilySearchResults(max_results=5)

# This executes code locally, which can be unsafe
repl = PythonREPL()


@tool
def python_repl_tool(
    code: Annotated[str, "The python code to execute to generate your chart."],
):
    """Use this to execute python code and do math. If you want to see the output of a value,
    you should print it out with `print(...)`. This is visible to the user."""
    try:
        result = repl.run(code)
    except BaseException as e:
        return f"Failed to execute. Error: {repr(e)}"
    result_str = f"Successfully executed:\n```python\n{code}\n```\nStdout: {result}"
    return result_str

# %% [markdown]
# ### Create Agent Supervisor
#
# It will use LLM with structured output to choose the next worker node OR finish processing.

# %%
from typing import Literal
from typing_extensions import TypedDict

from langchain_anthropic import ChatAnthropic
from langgraph.graph import MessagesState, END
from langgraph.types import Command


members = ["researcher", "coder"]
# Our team supervisor is an LLM node. It just picks the next agent to process
# and decides when the work is completed
options = members + ["FINISH"]

system_prompt = (
    "You are a supervisor tasked with managing a conversation between the"
    f" following workers: {members}. Given the following user request,"
    " respond with the worker to act next. Each worker will perform a"
    " task and respond with their results and status. When finished,"
    " respond with FINISH."
)


class Router(TypedDict):
    """Worker to route to next. If no workers needed, route to FINISH."""

    next: Literal[*options]


llm = ChatAnthropic(model="claude-3-5-sonnet-latest")


class State(MessagesState):
    next: str


def supervisor_node(state: State) -> Command[Literal[*members, "__end__"]]:
    messages = [
        {"role": "system", "content": system_prompt},
    ] + state["messages"]
    response = llm.with_structured_output(Router).invoke(messages)
    goto = response["next"]
    if goto == "FINISH":
        goto = END

    return Command(goto=goto, update={"next": goto})

# %% [markdown]
# ## Construct Graph
#
# We're ready to start building the graph. Below, define the state and worker nodes using the function we just defined.

# %%
from langchain_core.messages import HumanMessage
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import create_react_agent


research_agent = create_react_agent(
    llm, tools=[tavily_tool], prompt="You are a researcher. DO NOT do any math."
)


def research_node(state: State) -> Command[Literal["supervisor"]]:
    result = research_agent.invoke(state)
    return Command(
        update={
            "messages": [
                HumanMessage(content=result["messages"][-1].content, name="researcher")
            ]
        },
        goto="supervisor",
    )


# NOTE: THIS PERFORMS ARBITRARY CODE EXECUTION, WHICH CAN BE UNSAFE WHEN NOT SANDBOXED
code_agent = create_react_agent(llm, tools=[python_repl_tool])


def code_node(state: State) -> Command[Literal["supervisor"]]:
    result = code_agent.invoke(state)
    return Command(
        update={
            "messages": [
                HumanMessage(content=result["messages"][-1].content, name="coder")
            ]
        },
        goto="supervisor",
    )


builder = StateGraph(State)
builder.add_edge(START, "supervisor")
builder.add_node("supervisor", supervisor_node)
builder.add_node("researcher", research_node)
builder.add_node("coder", code_node)
graph = builder.compile()

# %%
from IPython.display import display, Image

display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Invoke the team
#
# With the graph created, we can now invoke it and see how it performs!

# %%
for s in graph.stream(
    {"messages": [("user", "What's the square root of 42?")]}, subgraphs=True
):
    print(s)
    print("----")
# Out:
# ((), {'supervisor': {'next': 'coder'}})
# ----
# Python REPL can execute arbitrary code. Use with caution.
# (('coder:9c96b7e1-5ae2-7636-abbb-9d8a306afd34',), {'agent': {'messages': [AIMessage(content=[{'text': "I'll help you calculate the square root of 42 using Python.", 'type': 'text'}, {'id': 'toolu_01M7FXMMrykRCZANESzsaUZr', 'input': {'code': 'import math\nprint(math.sqrt(42))'}, 'name': 'python_repl_tool', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01NJWDrFte5AQSVaUhyufdtX', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 435, 'output_tokens': 82}}, id='run-eb71dd6d-e527-42cb-91d3-65cc2bae506e-0', tool_calls=[{'name': 'python_repl_tool', 'args': {'code': 'import math\nprint(math.sqrt(42))'}, 'id': 'toolu_01M7FXMMrykRCZANESzsaUZr', 'type': 'tool_call'}], usage_metadata={'input_tokens': 435, 'output_tokens': 82, 'total_tokens': 517, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('coder:9c96b7e1-5ae2-7636-abbb-9d8a306afd34',), {'tools': {'messages': [ToolMessage(content='Successfully executed:\n```python\nimport math\nprint(math.sqrt(42))\n```\nStdout: 6.48074069840786\n', name='python_repl_tool', id='40447527-8ddb-4739-a441-9b67f9b2a55a', tool_call_id='toolu_01M7FXMMrykRCZANESzsaUZr')]}})
# ----
# (('coder:9c96b7e1-5ae2-7636-abbb-9d8a306afd34',), {'agent': {'messages': [AIMessage(content='The square root of 42 is approximately 6.4807.', additional_kwargs={}, response_metadata={'id': 'msg_012Ward5F651ciYc2VFVEe8c', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 561, 'output_tokens': 19}}, id='run-f6550327-ca6d-44a4-842f-974ca99d0870-0', usage_metadata={'input_tokens': 561, 'output_tokens': 19, 'total_tokens': 580, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# ((), {'coder': {'messages': [HumanMessage(content='The square root of 42 is approximately 6.4807.', additional_kwargs={}, response_metadata={}, name='coder')]}})
# ----
# ((), {'supervisor': {'next': '__end__'}})
# ----

# %%
for s in graph.stream(
    {
        "messages": [
            (
                "user",
                "Draw a diagram to show the stock price of Tesla over the past year.",
            )
        ]
    },
    subgraphs=True,
):
    print(s)
    print("----")
# Out:
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# (('researcher:79f91248-0eb4-5e6b-98c8-3fb8c8f22eb3',), {'agent': {'messages': [AIMessage(content=[{'text': "I'll help you search for the latest GDP figures for New York and California. Let me look up this information.", 'type': 'text'}, {'id': 'toolu_01FRQirUrGC1UeCoRsQCCgDa', 'input': {'query': 'latest GDP of New York state 2023'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01PugfnksBmi82JvzkjYH3BB', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 442, 'output_tokens': 90}}, id='run-49ffbacc-3385-4b50-88da-bc3108b7c89a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP of New York state 2023'}, 'id': 'toolu_01FRQirUrGC1UeCoRsQCCgDa', 'type': 'tool_call'}], usage_metadata={'input_tokens': 442, 'output_tokens': 90, 'total_tokens': 532, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:79f91248-0eb4-5e6b-98c8-3fb8c8f22eb3',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "content": "What is the gross domestic product (GDP) in New York? What is the gross domestic product (GDP) in New York? Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. As of 2023, the real GDP was $1.8 trillion. Real GDP in New York, adjusted for inflation (chained 2017 dollars) GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, New York\'s real (that is, inflation-adjusted) GDP per person was 1st out of all 50 states. In 2023, New York ranked 1st in state GDP per person."}, {"url": "https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/", "content": "Basic Statistic U.S. value added to GDP 2023, by industry Basic Statistic U.S. value added to GDP by services sector 2023, by industry Basic Statistic U.S. real GDP growth 2023, by state Basic Statistic U.S. real GDP of New York 2000-2023 Basic Statistic U.S. real GDP 2023, by metro area Basic Statistic U.S. real GDP of Maine 2000-2023 Basic Statistic U.S. real value added to GDP in Maryland 2023, by industry \\"Real Gross Domestic Product of New York in The United States from 2000 to 2023 (in Billion U.S. Dollars).\\" Statista, Statista Inc., 29 Mar 2024, https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/ BEA, Real gross domestic product of New York in the United States from 2000 to 2023 (in billion U.S. dollars) Statista, https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/ (last visited February 08, 2025)"}, {"url": "https://www.osc.ny.gov/reports/finance/2023-fcr/economic-and-demographic-trends", "content": "Economic and Demographic Trends – 2023 Financial Condition Report | Office of the New York State Comptroller The New York State Office of the State Comptroller\'s website is provided in English. The State of New York, its officers, employees, and/or agents are not liable to you, or to third parties, for damages or losses of any kind arising out of, or in connection with, the use or performance of such information. New York State Comptroller New York State Comptroller New York State and Local Retirement System (NYSLRS) New York State Budget Analysis and Financial Reporting New York State Financial Reporting New York State’s real GDP increased by 3.2 percent, compared to 2.1 percent nationally."}, {"url": "https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/", "content": "Basic Statistic U.S. real value added to GDP in New York 2023, by industry Basic Statistic U.S. real value added to GDP in New Hampshire 2023, by industry Basic Statistic U.S. real value added to GDP in New Mexico 2023, by industry \\"Real Value Added to The Gross Domestic Product of New York in The United States in 2023, by Industry (in Billion Chained 2017 U.S. Dollars).\\" Statista, Statista Inc., 27 Sep 2024, https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/ BEA, Real value added to the gross domestic product of New York in the United States in 2023, by industry (in billion chained 2017 U.S. dollars) Statista, https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/ (last visited February 08, 2025)"}, {"url": "https://www.bea.gov/news/2023/gross-domestic-product-state-and-personal-income-state-3rd-quarter-2023", "content": "Gross Domestic Product by State and Personal Income by State, 3rd Quarter 2023 | U.S. Bureau of Economic Analysis (BEA) Real gross domestic product (GDP) increased in all 50 states and the District of Columbia in the third quarter of 2023, with the  ...
# ----
# (('researcher:79f91248-0eb4-5e6b-98c8-3fb8c8f22eb3',), {'agent': {'messages': [AIMessage(content=[{'id': 'toolu_01TvSwJkF1LhD11bfJN6wb3y', 'input': {'query': 'latest GDP of California state 2023'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01Qr3vgMBdv2QndRrHKJ4PiT', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 1829, 'output_tokens': 66}}, id='run-63a767bb-60f6-467a-84ac-7c03944269d7-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP of California state 2023'}, 'id': 'toolu_01TvSwJkF1LhD11bfJN6wb3y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1829, 'output_tokens': 66, 'total_tokens': 1895, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:79f91248-0eb4-5e6b-98c8-3fb8c8f22eb3',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/california/", "content": "Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. The $3.2 trillion is the “real GDP,” which is adjusted to account for inflation to make it easier to compare the size of an economy over time. Real GDP (2023) As of 2023, the real GDP was $3.2 trillion. GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, California’s real (that is, inflation-adjusted) GDP per person was 4th highest out of all 50 states. In 2023, California ranked 4th in state GDP per person."}, {"url": "https://www.gov.ca.gov/2024/04/16/california-remains-the-worlds-5th-largest-economy/", "content": "California Remains the World’s 5th Largest Economy | Governor of California California Remains the World’s 5th Largest Economy SACRAMENTO – Thanks to continued economic growth and strong performances in a variety of industry sectors, California has again ranked as the 5th largest economy in the world. California remains the 5th largest economy in the world since 2017. California is the 5th largest economy in the world for the seventh consecutive year, with a nominal GDP of nearly $3.9 trillion in 2023 and a growth rate of 6.1% since the year prior, according to the U.S. Bureau of Economic Analysis (BEA). Footer Social Media Links"}, {"url": "https://www.statista.com/statistics/187834/gdp-of-the-us-federal-state-of-california-since-1997/", "content": "Basic Statistic U.S. real GDP of California 2000-2023 Premium Statistic U.S. annual GDP growth in California 2000-2023 Basic Statistic U.S. real value added to GDP in California 2023, by industry Premium Statistic U.S. California state government funding FY 2001-2024 Premium Statistic U.S. number of business establishments in California 2022, by industry Premium Statistic U.S. top companies in California 2021, by revenue Premium Statistic U.S. number of nonfarm employees in California 2023, by industry \\"Real Gross Domestic Product of California in The United States from 2000 to 2023 (in Billion U.S. Dollars).\\" Statista, Statista Inc., 29 Mar 2024, https://www.statista.com/statistics/187834/gdp-of-the-us-federal-state-of-california-since-1997/ BEA, Real gross domestic product of California in the United States from 2000 to 2023 (in billion U.S. dollars) Statista, https://www.statista.com/statistics/187834/gdp-of-the-us-federal-state-of-california-since-1997/ (last visited February 08, 2025)"}, {"url": "https://www.ppic.org/publication/californias-economy/", "content": "California’s Economy California’s economy has grown relatively slowly in recent years, averaging 2.3% per year between 2020 and 2023, compared to 3.9% on average over the previous four years. Over the long term, California’s economy has grown faster than the nation overall (111% vs 75% over the past 25 years) and faster than other large states except for Texas (128%). On a per capita basis, California’s economic growth outpaces all other large states over the long term. California’s employment growth is generally similar to that of the nation (averaging 1.2% and 1.0%, respectively, over the past 25 years); since the pandemic, the state’s employment growth has been a bit slower (0.9% vs 1.1% in the US)."}, {"url": "https://www.statista.com/statistics/248023/us-gross-domestic-product-gdp-by-state/", "content": "Basic Statistic U.S. real value added to GDP in Indiana 2023, by industry Basic Statistic U.S. real value added to GDP in Minnesota 2022, by industry Basic Statistic U.S. real value added to GDP in Arizona 2023, by industry Basic Statistic U.S. real value added to GDP in Kansas 2023, by ...
# ----
# (('researcher:79f91248-0eb4-5e6b-98c8-3fb8c8f22eb3',), {'agent': {'messages': [AIMessage(content="Based on the search results, I can provide you with the latest GDP figures for both states:\n\nNew York's GDP (2023): $1.8 trillion\nCalifornia's GDP (2023): $3.2 trillion (real GDP) / $3.9 trillion (nominal GDP)\n\nAs requested, I will not perform the mathematical calculation for the average, as that would involve doing math. However, I have provided you with the latest GDP figures for both states that you can use to calculate the average yourself.\n\nNote: There are two different figures reported for California - the real GDP (adjusted for inflation) of $3.2 trillion and the nominal GDP of $3.9 trillion. For a more accurate comparison, it would be better to use the real GDP figures for both states, as New York's figure of $1.8 trillion is also reported as real GDP.", additional_kwargs={}, response_metadata={'id': 'msg_01SDjgNCtjoNe1o4X2yt9EfL', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 3098, 'output_tokens': 191}}, id='run-e1bcc948-6190-41b4-b160-606c260da344-0', usage_metadata={'input_tokens': 3098, 'output_tokens': 191, 'total_tokens': 3289, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# ((), {'researcher': {'messages': [HumanMessage(content="Based on the search results, I can provide you with the latest GDP figures for both states:\n\nNew York's GDP (2023): $1.8 trillion\nCalifornia's GDP (2023): $3.2 trillion (real GDP) / $3.9 trillion (nominal GDP)\n\nAs requested, I will not perform the mathematical calculation for the average, as that would involve doing math. However, I have provided you with the latest GDP figures for both states that you can use to calculate the average yourself.\n\nNote: There are two different figures reported for California - the real GDP (adjusted for inflation) of $3.2 trillion and the nominal GDP of $3.9 trillion. For a more accurate comparison, it would be better to use the real GDP figures for both states, as New York's figure of $1.8 trillion is also reported as real GDP.", additional_kwargs={}, response_metadata={}, name='researcher')]}})
# ----
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# (('researcher:dcfd53fa-8122-d27a-9b32-b192096b0fd4',), {'agent': {'messages': [AIMessage(content=[{'text': 'Let me search for the most recent GDP figures for both states.', 'type': 'text'}, {'id': 'toolu_01PdutCkJJUVfB1Nuo8y4kkM', 'input': {'query': 'latest GDP New York state California 2023'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01UTJCFbYeaLu8Nr8W7yTZ9v', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 631, 'output_tokens': 80}}, id='run-5d84a5cb-3b39-45ab-8f41-c6b18c00e26e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP New York state California 2023'}, 'id': 'toolu_01PdutCkJJUVfB1Nuo8y4kkM', 'type': 'tool_call'}], usage_metadata={'input_tokens': 631, 'output_tokens': 80, 'total_tokens': 711, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:dcfd53fa-8122-d27a-9b32-b192096b0fd4',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://www.gov.ca.gov/2024/04/16/california-remains-the-worlds-5th-largest-economy/", "content": "California Remains the World’s 5th Largest Economy | Governor of California California Remains the World’s 5th Largest Economy SACRAMENTO – Thanks to continued economic growth and strong performances in a variety of industry sectors, California has again ranked as the 5th largest economy in the world. California remains the 5th largest economy in the world since 2017. California is the 5th largest economy in the world for the seventh consecutive year, with a nominal GDP of nearly $3.9 trillion in 2023 and a growth rate of 6.1% since the year prior, according to the U.S. Bureau of Economic Analysis (BEA). Footer Social Media Links"}, {"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states and the national capital of Washington, D.C. and the GDP change and GDP per capita as of 2024.[1][3] The Bureau of Economic Analysis (BEA) collects GDP data for four U.S. territories (American Samoa, Guam, the Northern Mariana Islands, and the U.S. Virgin Islands) separately from the states and the District of Columbia. List of U.S. states and territories by GDP per capita"}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}, {"url": "https://usafacts.org/articles/how-does-gdp-differ-by-state/", "content": "Which states contribute the most and the least to the GDP? Which states have the highest and lowest GDP per capita? In 2022, the real GDP per capita was highest in New York ($104,100), the only state that topped $100,000. What is each state’s biggest contributor to the nation’s GDP? Professional and business services — including industries like finance and insurance — contribute the most to the GDPs of 10 states, including several of the largest contributors to national GDP, such as California and Illinois. From 2021 to 2022, real GDP increased in 43 states and Washington, DC, led by Florida (4.6%), Idaho (4.2%), and Tennessee (3.9%). GDP by State"}, {"url": "https://www.statista.com/statistics/248053/us-real-gross-domestic-product-gdp-by-state/", "content": "Basic Statistic U.S. real value added to GDP in Indiana 2023, by industry Basic Statistic U.S. real value added to GDP in Minnesota 2022, by industry Basic Statistic U.S. real value added to GDP in Arizona 2023, by industry Basic Statistic U.S. real value added to GDP in Kansas 2023, by industry Basic Statistic U.S. real value added to GDP in New Hampshire 2023, by industry Basic Statistic U.S. real value added to GDP in Michigan 2023, by i ...
# ----
# (('researcher:dcfd53fa-8122-d27a-9b32-b192096b0fd4',), {'agent': {'messages': [AIMessage(content=[{'text': "Let me search specifically for New York's latest GDP figures.", 'type': 'text'}, {'id': 'toolu_01EKp5AnpZmfJc25bnmaKvz4', 'input': {'query': 'New York state GDP 2023 2024 total amount'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01YRw4CNhJX9qvyETp5Wj4Sx', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 1867, 'output_tokens': 84}}, id='run-cd7099d9-23d4-4a9b-8bcf-82dac58a4e5e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'New York state GDP 2023 2024 total amount'}, 'id': 'toolu_01EKp5AnpZmfJc25bnmaKvz4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1867, 'output_tokens': 84, 'total_tokens': 1951, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:dcfd53fa-8122-d27a-9b32-b192096b0fd4',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states and the national capital of Washington, D.C. and the GDP change and GDP per capita as of 2024.[1][3] The Bureau of Economic Analysis (BEA) collects GDP data for four U.S. territories (American Samoa, Guam, the Northern Mariana Islands, and the U.S. Virgin Islands) separately from the states and the District of Columbia. List of U.S. states and territories by GDP per capita"}, {"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "content": "What is the gross domestic product (GDP) in New York? What is the gross domestic product (GDP) in New York? Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. As of 2023, the real GDP was $1.8 trillion. Real GDP in New York, adjusted for inflation (chained 2017 dollars) GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, New York\'s real (that is, inflation-adjusted) GDP per person was 1st out of all 50 states. In 2023, New York ranked 1st in state GDP per person."}, {"url": "https://comptroller.nyc.gov/newsroom/newsletter/new-york-by-the-numbers-monthly-economic-and-fiscal-outlook-no-97-january-15-2025/", "content": "The balance of domestic migration improved further, by another 56,000 in 2024 to -120,900."}, {"url": "https://www.osc.ny.gov/reports/finance/2023-fcr/economic-and-demographic-trends", "content": "Economic and Demographic Trends – 2023 Financial Condition Report | Office of the New York State Comptroller The New York State Office of the State Comptroller\'s website is provided in English. The State of New York, its officers, employees, and/or agents are not liable to you, or to third parties, for damages or losses of any kind arising out of, or in connection with, the use or performance of such information. New York State Comptroller New York State Comptroller New York State and Local Retirement System (NYSLRS) New York State Budget Analysis and Financial Reporting New York State Financial Reporting New York State’s real GDP increased by 3.2 percent, compared to 2.1 percent nationally."}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}]', name='tavily_search_results_json', id='8dda38d1-1d04-4fdb-8baf-5a9e1f06d9f8', tool_call_id='toolu_01EKp5AnpZmfJc25bnmaKvz4', artifact={'query': 'New Yo ...
# ----
# (('researcher:dcfd53fa-8122-d27a-9b32-b192096b0fd4',), {'agent': {'messages': [AIMessage(content="Based on the search results, I can provide you with the latest GDP figures for both states:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nNote: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={'id': 'msg_01XTmiZQamQWygm3rfeKhLCJ', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 2932, 'output_tokens': 180}}, id='run-bfcd1da9-0845-416e-8caf-d6c1e10b4a72-0', usage_metadata={'input_tokens': 2932, 'output_tokens': 180, 'total_tokens': 3112, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# ((), {'researcher': {'messages': [HumanMessage(content="Based on the search results, I can provide you with the latest GDP figures for both states:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nNote: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={}, name='researcher')]}})
# ----
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# (('researcher:96aaec66-8d86-b094-6981-eded2a5ff6cc',), {'agent': {'messages': [AIMessage(content=[{'text': 'Let me search for the latest GDP figures for both states to ensure accuracy.', 'type': 'text'}, {'id': 'toolu_01X3WFvACYVkoW9o3HbtyTLU', 'input': {'query': 'latest GDP New York state California state 2023'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01PUmN6Uf5yqzCHbmh6BtZXx', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 807, 'output_tokens': 83}}, id='run-2862ae5f-4a88-40b6-ad82-d80ef8359999-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP New York state California state 2023'}, 'id': 'toolu_01X3WFvACYVkoW9o3HbtyTLU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 807, 'output_tokens': 83, 'total_tokens': 890, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:96aaec66-8d86-b094-6981-eded2a5ff6cc',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://www.gov.ca.gov/2024/04/16/california-remains-the-worlds-5th-largest-economy/", "content": "California Remains the World’s 5th Largest Economy | Governor of California California Remains the World’s 5th Largest Economy SACRAMENTO – Thanks to continued economic growth and strong performances in a variety of industry sectors, California has again ranked as the 5th largest economy in the world. California remains the 5th largest economy in the world since 2017. California is the 5th largest economy in the world for the seventh consecutive year, with a nominal GDP of nearly $3.9 trillion in 2023 and a growth rate of 6.1% since the year prior, according to the U.S. Bureau of Economic Analysis (BEA). Footer Social Media Links"}, {"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states and the national capital of Washington, D.C. and the GDP change and GDP per capita as of 2024.[1][3] The Bureau of Economic Analysis (BEA) collects GDP data for four U.S. territories (American Samoa, Guam, the Northern Mariana Islands, and the U.S. Virgin Islands) separately from the states and the District of Columbia. List of U.S. states and territories by GDP per capita"}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}, {"url": "https://usafacts.org/articles/how-does-gdp-differ-by-state/", "content": "Which states contribute the most and the least to the GDP? Which states have the highest and lowest GDP per capita? In 2022, the real GDP per capita was highest in New York ($104,100), the only state that topped $100,000. What is each state’s biggest contributor to the nation’s GDP? Professional and business services — including industries like finance and insurance — contribute the most to the GDPs of 10 states, including several of the largest contributors to national GDP, such as California and Illinois. From 2021 to 2022, real GDP increased in 43 states and Washington, DC, led by Florida (4.6%), Idaho (4.2%), and Tennessee (3.9%). GDP by State"}, {"url": "https://www.statista.com/statistics/248023/us-gross-domestic-product-gdp-by-state/", "content": "Basic Statistic U.S. real value added to GDP in Indiana 2023, by industry Basic Statistic U.S. real value added to GDP in Minnesota 2022, by industry Basic Statistic U.S. real value added to GDP in Arizona 2023, by industry Basic Statistic U.S. real value added to GDP in Kansas 2023, by industry Basic Statistic U.S. real value added to GDP in New Hampshire 2023, by industry Basic Statistic U.S. real value added to GDP in Michigan 2023, by indust ...
# ----
# (('researcher:96aaec66-8d86-b094-6981-eded2a5ff6cc',), {'agent': {'messages': [AIMessage(content=[{'text': "Let me search specifically for New York's latest GDP figures to ensure we have the most current data.", 'type': 'text'}, {'id': 'toolu_01GZTQWVrHbhJHfbo7Df666h', 'input': {'query': 'New York state GDP 2023 2024 total amount'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_017ee3GrRrLpsv3phASx74Bx', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 1982, 'output_tokens': 92}}, id='run-268ac9b1-0b7a-414a-89ef-74ac8d97db1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'New York state GDP 2023 2024 total amount'}, 'id': 'toolu_01GZTQWVrHbhJHfbo7Df666h', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1982, 'output_tokens': 92, 'total_tokens': 2074, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:96aaec66-8d86-b094-6981-eded2a5ff6cc',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states and the national capital of Washington, D.C. and the GDP change and GDP per capita as of 2024.[1][3] The Bureau of Economic Analysis (BEA) collects GDP data for four U.S. territories (American Samoa, Guam, the Northern Mariana Islands, and the U.S. Virgin Islands) separately from the states and the District of Columbia. List of U.S. states and territories by GDP per capita"}, {"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "content": "What is the gross domestic product (GDP) in New York? What is the gross domestic product (GDP) in New York? Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. As of 2023, the real GDP was $1.8 trillion. Real GDP in New York, adjusted for inflation (chained 2017 dollars) GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, New York\'s real (that is, inflation-adjusted) GDP per person was 1st out of all 50 states. In 2023, New York ranked 1st in state GDP per person."}, {"url": "https://comptroller.nyc.gov/newsroom/newsletter/new-york-by-the-numbers-monthly-economic-and-fiscal-outlook-no-97-january-15-2025/", "content": "The balance of domestic migration improved further, by another 56,000 in 2024 to -120,900."}, {"url": "https://www.osc.ny.gov/reports/finance/2023-fcr/economic-and-demographic-trends", "content": "Economic and Demographic Trends – 2023 Financial Condition Report | Office of the New York State Comptroller The New York State Office of the State Comptroller\'s website is provided in English. The State of New York, its officers, employees, and/or agents are not liable to you, or to third parties, for damages or losses of any kind arising out of, or in connection with, the use or performance of such information. New York State Comptroller New York State Comptroller New York State and Local Retirement System (NYSLRS) New York State Budget Analysis and Financial Reporting New York State Financial Reporting New York State’s real GDP increased by 3.2 percent, compared to 2.1 percent nationally."}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}]', name='tavily_search_results_json', id='0580f1cc-46cf-44c0-b1d4-187b3be4346f', tool_call_id='toolu_01GZTQWVrHbhJHfbo7Df666h', artifact={'query': 'New Yo ...
# ----
# (('researcher:96aaec66-8d86-b094-6981-eded2a5ff6cc',), {'agent': {'messages': [AIMessage(content="Based on the most recent data from reliable sources:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nImportant Note: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={'id': 'msg_01CQjt9LqfDQz9c1QorYHZgg', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 3055, 'output_tokens': 172}}, id='run-f495263e-3e3f-4b01-97de-11447f5b900e-0', usage_metadata={'input_tokens': 3055, 'output_tokens': 172, 'total_tokens': 3227, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# ((), {'researcher': {'messages': [HumanMessage(content="Based on the most recent data from reliable sources:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nImportant Note: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={}, name='researcher')]}})
# ----
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# (('researcher:ffc839fe-6b3a-d549-8c57-e60b065c1647',), {'agent': {'messages': [AIMessage(content=[{'text': 'Let me search for the most up-to-date GDP figures for both states.', 'type': 'text'}, {'id': 'toolu_01HcL34xLQj96NC7hJCZS3cM', 'input': {'query': 'latest GDP New York state 2023 2024'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01F2oCk1GCsEuGLuZMSFD5f3', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 975, 'output_tokens': 86}}, id='run-0c105e74-eb14-4482-b89b-4f87b6af465d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP New York state 2023 2024'}, 'id': 'toolu_01HcL34xLQj96NC7hJCZS3cM', 'type': 'tool_call'}], usage_metadata={'input_tokens': 975, 'output_tokens': 86, 'total_tokens': 1061, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:ffc839fe-6b3a-d549-8c57-e60b065c1647',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "content": "What is the gross domestic product (GDP) in New York? What is the gross domestic product (GDP) in New York? Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. As of 2023, the real GDP was $1.8 trillion. Real GDP in New York, adjusted for inflation (chained 2017 dollars) GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, New York\'s real (that is, inflation-adjusted) GDP per person was 1st out of all 50 states. In 2023, New York ranked 1st in state GDP per person."}, {"url": "https://www.osc.ny.gov/reports/finance/2023-fcr/economic-and-demographic-trends", "content": "Economic and Demographic Trends – 2023 Financial Condition Report | Office of the New York State Comptroller The New York State Office of the State Comptroller\'s website is provided in English. The State of New York, its officers, employees, and/or agents are not liable to you, or to third parties, for damages or losses of any kind arising out of, or in connection with, the use or performance of such information. New York State Comptroller New York State Comptroller New York State and Local Retirement System (NYSLRS) New York State Budget Analysis and Financial Reporting New York State Financial Reporting New York State’s real GDP increased by 3.2 percent, compared to 2.1 percent nationally."}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}, {"url": "http://www.bea.gov/news/2024/gross-domestic-product-state-and-personal-income-state-1st-quarter-2024", "content": "Real gross domestic product increased in 39 states and the District of Columbia in the first quarter of 2024, with the percent change ranging from 5.0 percent at an annual rate in Idaho to –4.2 percent in South Dakota, according to statistics released today by the U.S. Bureau of Economic Analysis (BEA) (table 1). Current-dollar gross domestic product (GDP) increased in 45 states and the District of Columbia, with the percent change ranging from 7.8 percent at an annual rate in Delaware to –4.0 percent in North Dakota (table 1). Personal income, in current dollars, increased in all 50 states and the District of Columbia, with the percent change ranging from 9.5 percent at an annual rate in South Carolina to 0.6 percent in North Dakota (table 3)."}, {"url": "https://tradingeconomics.com/united-states/total-gross-domestic-product-by-industry-for-new-york-fed-data.html", "content": "Interest Rate Inflation Rate Trading Economics provides the current actual value, an historical data chart and related indicators for Gross Domestic Product: All Industry Total in New York - last updated from the United States Federal Reserve on February of 2025. GDP Growth Rate Core Inflation Rate MoM Core Inflation Rate YoY Core PCE Price Index MoM Core PCE Price Index YoY Export Prices MoM GDP Price Index Import Prices MoM Inflation  ...
# ----
# (('researcher:ffc839fe-6b3a-d549-8c57-e60b065c1647',), {'agent': {'messages': [AIMessage(content=[{'id': 'toolu_01MvFF5fo9nyyiPNMSEwePyv', 'input': {'query': 'latest GDP California state 2023 2024'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01PViK6JBJoBMnPgNAmVHdUP', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 2135, 'output_tokens': 68}}, id='run-45121913-0ea0-4787-bac3-c81bc038373f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP California state 2023 2024'}, 'id': 'toolu_01MvFF5fo9nyyiPNMSEwePyv', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2135, 'output_tokens': 68, 'total_tokens': 2203, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:ffc839fe-6b3a-d549-8c57-e60b065c1647',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/california/", "content": "Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. The $3.2 trillion is the “real GDP,” which is adjusted to account for inflation to make it easier to compare the size of an economy over time. Real GDP (2023) As of 2023, the real GDP was $3.2 trillion. GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, California’s real (that is, inflation-adjusted) GDP per person was 4th highest out of all 50 states. In 2023, California ranked 4th in state GDP per person."}, {"url": "https://www.gov.ca.gov/2024/04/16/california-remains-the-worlds-5th-largest-economy/", "content": "California Remains the World’s 5th Largest Economy | Governor of California California Remains the World’s 5th Largest Economy SACRAMENTO – Thanks to continued economic growth and strong performances in a variety of industry sectors, California has again ranked as the 5th largest economy in the world. California remains the 5th largest economy in the world since 2017. California is the 5th largest economy in the world for the seventh consecutive year, with a nominal GDP of nearly $3.9 trillion in 2023 and a growth rate of 6.1% since the year prior, according to the U.S. Bureau of Economic Analysis (BEA). Footer Social Media Links"}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}, {"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states and the national capital of Washington, D.C. and the GDP change and GDP per capita as of 2024.[1][3] The Bureau of Economic Analysis (BEA) collects GDP data for four U.S. territories (American Samoa, Guam, the Northern Mariana Islands, and the U.S. Virgin Islands) separately from the states and the District of Columbia. List of U.S. states and territories by GDP per capita"}, {"url": "http://www.bea.gov/news/2024/gross-domestic-product-state-and-personal-income-state-2nd-quarter-2024", "content": "Real gross domestic product increased in 49 states and the District of Columbia in the second quarter of 2024, with the percent change ranging from 5.9 percent at an annual rate in Idaho to –1.1 percent in Alaska, according to statistics released today by the U.S. Bureau of Economic Analysis (table 1). Earnings increased in 22 of the 24 i ...
# ----
# ...
# ----
# ((), {'researcher': {'messages': [HumanMessage(content="Based on the search results, here are the latest GDP figures for both states:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nImportant Note: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={}, name='researcher')]}})
# ----
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# (('researcher:29f04519-5f9a-ad1f-c0c0-f105b9733d28',), {'agent': {'messages': [AIMessage(content=[{'text': 'Let me search for the latest GDP figures for both states.', 'type': 'text'}, {'id': 'toolu_01Des22EC9N5Jd2bGxBpm8Ue', 'input': {'query': 'latest GDP California New York state 2023'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_018JEt6KBAtwcwD5RopZc84t', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 2388, 'output_tokens': 79}}, id='run-ee329ecc-1044-497a-b368-6169b5e980da-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'latest GDP California New York state 2023'}, 'id': 'toolu_01Des22EC9N5Jd2bGxBpm8Ue', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2388, 'output_tokens': 79, 'total_tokens': 2467, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:29f04519-5f9a-ad1f-c0c0-f105b9733d28',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://www.gov.ca.gov/2024/04/16/california-remains-the-worlds-5th-largest-economy/", "content": "California Remains the World’s 5th Largest Economy | Governor of California California Remains the World’s 5th Largest Economy SACRAMENTO – Thanks to continued economic growth and strong performances in a variety of industry sectors, California has again ranked as the 5th largest economy in the world. California remains the 5th largest economy in the world since 2017. California is the 5th largest economy in the world for the seventh consecutive year, with a nominal GDP of nearly $3.9 trillion in 2023 and a growth rate of 6.1% since the year prior, according to the U.S. Bureau of Economic Analysis (BEA). Footer Social Media Links"}, {"url": "https://www.bea.gov/news/2023/gross-domestic-product-state-and-personal-income-state-3rd-quarter-2023", "content": "Gross Domestic Product by State and Personal Income by State, 3rd Quarter 2023 | U.S. Bureau of Economic Analysis (BEA) Real gross domestic product (GDP) increased in all 50 states and the District of Columbia in the third quarter of 2023, with the percent change ranging from 9.7 percent in Kansas to 0.7 percent in Arkansas (table 1), according to statistics released today by the U.S. Bureau of Economic Analysis (BEA). Current-dollar personal income increased in 49 states and the District of Columbia in the third quarter of 2023, with the percent change ranging from 5.2 percent in Texas to 0.0 percent in Arkansas (table 3). Today, BEA also released revised quarterly estimates of personal income by state for the first and second quarters of 2023."}, {"url": "https://www.bea.gov/data/gdp/gdp-state", "content": "GDP by State | U.S. Bureau of Economic Analysis (BEA) Data BEA Data GDP by State GDP by State Real gross domestic product increased in 46 states and the District of Columbia in the third quarter of 2024, with the percent change ranging from 6.9 percent at an annual rate in Arkansas to –2.3 percent in North Dakota. 2023 Comprehensive Update of the Regional Economic Accounts Provides details about the update, including background materials, data availability, and table changes. Interactive Tables: GDP by state BEARFACTS BEA Regional Fact Sheet about personal income and gross domestic product. Component States in BEA Regions What is GDP by State? The data include breakdowns of industries\' contributions to each state economy."}, {"url": "https://www.ppic.org/publication/californias-economy/", "content": "California’s Economy California’s economy has grown relatively slowly in recent years, averaging 2.3% per year between 2020 and 2023, compared to 3.9% on average over the previous four years. Over the long term, California’s economy has grown faster than the nation overall (111% vs 75% over the past 25 years) and faster than other large states except for Texas (128%). On a per capita basis, California’s economic growth outpaces all other large states over the long term. California’s employment growth is generally similar to that of the nation (averaging 1.2% and 1.0%, respectively, over the past 25 years); since the pandemic, the state’s employment growth has been a bit slower (0.9% vs 1.1% in the US)."}, {"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "content": "GDP per capita also varied widely throughout the United States in 2024, with New York ($117,332), Massachusetts ($110,561), and Washington (state) ($108,468) recording the three highest GDP per capita figures in the U.S., while Mississippi ($53,061), Arkansas ($60,276), and West Virginia ($60,783) recorded the three lowest GDP per capita figures in the U.S. The District of Columbia, though, recorded a GDP per capita figure far higher than any U.S. state in 2024 at $263,220. The following list includes the annual nominal gross domestic product for each of the 50 U.S. states  ...
# ----
# (('researcher:29f04519-5f9a-ad1f-c0c0-f105b9733d28',), {'agent': {'messages': [AIMessage(content=[{'text': "Let me search specifically for New York's GDP data as well.", 'type': 'text'}, {'id': 'toolu_01VdWQBLQi8RqDdSymKPkxhv', 'input': {'query': 'New York state GDP 2023 real GDP'}, 'name': 'tavily_search_results_json', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_01FhMfJRBuML66avmFiuAmma', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 3578, 'output_tokens': 82}}, id='run-4949aa75-6487-425e-a878-912fdce3bad6-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'New York state GDP 2023 real GDP'}, 'id': 'toolu_01VdWQBLQi8RqDdSymKPkxhv', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3578, 'output_tokens': 82, 'total_tokens': 3660, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# (('researcher:29f04519-5f9a-ad1f-c0c0-f105b9733d28',), {'tools': {'messages': [ToolMessage(content='[{"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "content": "What is the gross domestic product (GDP) in New York? What is the gross domestic product (GDP) in New York? Gross domestic product (GDP) measures the value of goods and services a country or state produces — it’s the sum of consumer spending, business investment, government spending, and net exports. As of 2023, the real GDP was $1.8 trillion. Real GDP in New York, adjusted for inflation (chained 2017 dollars) GDP and the economic experience vary by location due to factors like cost of living, population density, workforce education, and the area’s main industries. In 2023, New York\'s real (that is, inflation-adjusted) GDP per person was 1st out of all 50 states. In 2023, New York ranked 1st in state GDP per person."}, {"url": "https://www.osc.ny.gov/reports/finance/2023-fcr/economic-and-demographic-trends", "content": "Economic and Demographic Trends – 2023 Financial Condition Report | Office of the New York State Comptroller The New York State Office of the State Comptroller\'s website is provided in English. The State of New York, its officers, employees, and/or agents are not liable to you, or to third parties, for damages or losses of any kind arising out of, or in connection with, the use or performance of such information. New York State Comptroller New York State Comptroller New York State and Local Retirement System (NYSLRS) New York State Budget Analysis and Financial Reporting New York State Financial Reporting New York State’s real GDP increased by 3.2 percent, compared to 2.1 percent nationally."}, {"url": "https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/", "content": "Basic Statistic U.S. value added to GDP 2023, by industry Basic Statistic U.S. value added to GDP by services sector 2023, by industry Basic Statistic U.S. real GDP growth 2023, by state Basic Statistic U.S. real GDP of New York 2000-2023 Basic Statistic U.S. real GDP 2023, by metro area Basic Statistic U.S. real GDP of Maine 2000-2023 Basic Statistic U.S. real value added to GDP in Maryland 2023, by industry \\"Real Gross Domestic Product of New York in The United States from 2000 to 2023 (in Billion U.S. Dollars).\\" Statista, Statista Inc., 29 Mar 2024, https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/ BEA, Real gross domestic product of New York in the United States from 2000 to 2023 (in billion U.S. dollars) Statista, https://www.statista.com/statistics/188087/gdp-of-the-us-federal-state-of-new-york-since-1997/ (last visited February 08, 2025)"}, {"url": "https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/", "content": "Basic Statistic U.S. real value added to GDP in New York 2023, by industry Basic Statistic U.S. real value added to GDP in New Hampshire 2023, by industry Basic Statistic U.S. real value added to GDP in New Mexico 2023, by industry \\"Real Value Added to The Gross Domestic Product of New York in The United States in 2023, by Industry (in Billion Chained 2017 U.S. Dollars).\\" Statista, Statista Inc., 27 Sep 2024, https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/ BEA, Real value added to the gross domestic product of New York in the United States in 2023, by industry (in billion chained 2017 U.S. dollars) Statista, https://www.statista.com/statistics/304883/new-york-real-gdp-by-industry/ (last visited February 08, 2025)"}, {"url": "https://esd.ny.gov/sites/default/files/Economic-Indicators-Dashboard-2023-12.pdf", "content": "6,000 6,500 7,000 7,500 8,000 8,500 Jan-13 Jan-14 Jan-15 Jan-16 Jan-17 Jan-18 Jan-19 Jan-20 Jan-21 Jan-22 Jan-23 Oct-23 Sep-23 Aug-23 Jul-23 Jun-23 May-23 Apr-23 Mar-23 Feb-23 Jan-23 Dec-22 Nov-22 Oct-22 Private Employment (SA, \'000s) 8,252 8,262 8,254 8,248 8,241 8,24 ...
# ----
# (('researcher:29f04519-5f9a-ad1f-c0c0-f105b9733d28',), {'agent': {'messages': [AIMessage(content="Based on the latest data from reliable sources:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nImportant Note: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={'id': 'msg_013Qg5g4Lm6nk5Eivp87CwCn', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 5105, 'output_tokens': 171}}, id='run-4a86cf9e-c576-4991-848a-6562555cd1db-0', usage_metadata={'input_tokens': 5105, 'output_tokens': 171, 'total_tokens': 5276, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})]}})
# ----
# ((), {'researcher': {'messages': [HumanMessage(content="Based on the latest data from reliable sources:\n\nCalifornia:\n- Nominal GDP (2023): $3.9 trillion\n- Growth rate: 6.1% from previous year\n\nNew York:\n- Real GDP (2023): $1.8 trillion\n- Growth rate: 3.2% compared to 2.1% nationally\n\nImportant Note: The figures are reported differently (nominal vs. real GDP) which makes direct comparison challenging. Real GDP is adjusted for inflation while nominal GDP is not. For the most accurate comparison, we would need both figures in the same terms (either both real or both nominal GDP).\n\nAs requested, I will not calculate the average since that would involve mathematical operations. I've provided you with the raw figures so you can perform that calculation yourself.", additional_kwargs={}, response_metadata={}, name='researcher')]}})
# ----
# ((), {'supervisor': {'next': 'researcher'}})
# ----
# ---------------------------------------------------------------------------
# GraphRecursionError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for s in graph.stream(
#       2     {
#       3         "messages": [
#       4             (
#       5                 "user",
#       6                 "Find the latest GDP of New York and California, then calculate the average",
#       7             )
#       8         ]
#       9     },
#      10     subgraphs=True,
#      11 ):
#      12     print(s)
#      13     print("----")
#
# File ~/Documents/advanced_agentic_research/multi_agentic_research/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1799, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1790 if loop.status == "out_of_steps":
#    1791     msg = create_error_message(
#    1792         message=(
#    1793             f"Recursion limit of {config['recursion_limit']} reached "
#    (...)
#    1797         error_code=ErrorCode.GRAPH_RECURSION_LIMIT,
#    1798     )
# -> 1799     raise GraphRecursionError(msg)
#    1800 # set final channel values as run output
#    1801 run_manager.on_chain_end(loop.output)
#
# GraphRecursionError: Recursion limit of 25 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT
